# %%
from langgraph.graph import Graph
# Out:
# Running cells with 'venv (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\Asus\Desktop\Agentic AI\venv ipykernel --update-deps --force-reinstall'
